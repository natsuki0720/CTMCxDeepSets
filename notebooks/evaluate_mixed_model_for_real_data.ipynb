# %%
import sys
import os
sys.path.append(os.path.abspath("../"))  # or "../../" depending on location

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from torch.utils.data import DataLoader
from utils.likelihood import *
from utils.formate_matrix_toMLData import *
from models.model_0929 import *
# import matplotlib.pyplot as plt
import japanize_matplotlib
# plt.rcParams["font.family"]="Open Sans"
# plt.rcParams["font.size"] = 22
np.set_printoptions(suppress=True)

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib as mpl
plt.rcParams["font.size"] = 14
font_path = "/Users/yamashitanatsuki/Library/Fonts/OpenSans-VariableFont_wdth,wght.ttf"

# フォントを Matplotlib に登録
fm.fontManager.addfont(font_path)

# フォント名取得（登録後の認識名を確認）
font_prop = fm.FontProperties(fname=font_path)
font_name = font_prop.get_name()
print("Registered Font Name:", font_name)

# rcParams に反映
mpl.rcParams['font.family'] = font_name
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42
plt.plot([1,2,3])
plt.title("Using Open Sans Variable Font")
plt.show()
# Out:
# Registered Font Name: Open Sans

# %%
device = torch.device("cpu")
model = DeepSets_varSets_forDiagnel(device=device).to(device)
model.load_state_dict(torch.load("../model_weights/mixed_distribution/mixed_0929.pth", map_location=device))
model.eval()
# Out:
# /var/folders/k3/b1t1gjg12pg0ycfdgpm2k7g00000gn/T/ipykernel_52197/3362759427.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("../model_weights/mixed_distribution/mixed_0929.pth", map_location=device))
# DeepSets_varSets_forDiagnel(
#   (embedding): Embedding(5, 16, padding_idx=0)
#   (fc1): Linear(in_features=33, out_features=256, bias=True)
#   (ln1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#   (fc2): Linear(in_features=256, out_features=512, bias=True)
#   (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   (drop): Dropout(p=0.2, inplace=False)
#   (att_fc): Linear(in_features=512, out_features=512, bias=True)
#   (att_score): Linear(in_features=512, out_features=1, bias=True)
#   (out_fc1): Linear(in_features=512, out_features=128, bias=True)
#   (out_ln1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (out_fc2): Linear(in_features=128, out_features=64, bias=True)
#   (out_ln2): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#   (out_fc3): Linear(in_features=64, out_features=3, bias=True)
# )

# %%
data_name = "data_DB2021"  

real_data_dir = f"../real_data/{data_name}.csv"
if data_name == "RCBridge":
    df = pd.read_csv(real_data_dir, delimiter=",",header = None)
else:
    df = pd.read_csv(real_data_dir, delimiter=",")
display(df.head())
print(df.columns)
# Out:
#    橋梁ID  点検年1   BCI1  点検年2  BCI2  Unnamed: 5
# 0     1  1977  100.0  2001  74.8          24
# 1     1  2002   74.9  2004  70.6           2
# 2     1  2004   70.6  2006  70.5           2
# 3     1  2012   74.2  2014  74.2           2
# 4     1  2014   74.2  2016  73.9           2
# Index(['橋梁ID', '点検年1', 'BCI1', '点検年2', 'BCI2', 'Unnamed: 5'], dtype='object')

# %%
if data_name == "suidou":
    df = df.rename(columns={'建設時健全度（1と仮定）': "pre", '調査時健全度': "post", '経過年数': "time"})
    df = df[df["pre"] < 4]
    df = df[df["post"] < 5]
if data_name == "shoban":
    df = df.rename(columns={'Be(1-4)': "pre", 'Af(1-4)': "post", 'Ins': "time"})
    # df = df[df["pre"] < 4]
    # df = df[df["post"] < 5]
if data_name == "Frank":
    def grading(x):
        if x <= 3:
            return 1
        elif x <= 5.5:
            return 2
        elif x <= 8:
            return 3
        else: return 4
    df["Pre_IRI_Class"] = df['Pre-State IRI'].apply(grading)
    df["Post_IRI_Class"] = df['Post-State IRI'].apply(grading)
    df["time"] = df['Inspection Time of PostState IRI']-df['Inspection Time of Prestate']
    df = df.rename(columns={'Pre_IRI_Class': "pre", 'Post_IRI_Class': "post"})
    display(df[["pre","post"]])
    df["post"] = df["post"].astype(int)
    # df["pre"] = df["pre"].astype(int)
    
if data_name == "Tunnel":
    df = df.rename(columns={'事前健全度': "pre", '事後健全度': "post", '検査間隔(年)': "time"})
    df = df[["pre", "post", "time"]]
    df = df.dropna()
    df["pre"] = df["pre"].astype(int)
    df["post"] = df["post"].astype(int)

if data_name == "data_DB2021":
    def grading_DB2021(x):
        if x >= 80:
            return 1
        elif x >=60:
            return 2
        elif x >= 40:
            return 3
        else: return 4
    df["pre"] = df['BCI1'].apply(grading_DB2021)
    df["post"] = df['BCI2'].apply(grading_DB2021)
    df["time"] = df['点検年2']-df['点検年1']
    df = df[df["pre"]<4]
    

if data_name == "RCBridge":
    df = df.rename(columns={0: "pre", 1: "post", 2: "time"})
    df = df[df["pre"] < 4]
    df = df[df["post"] < 5]

# %%
display(df.head())
# Out:
#    橋梁ID  点検年1   BCI1  点検年2  BCI2  Unnamed: 5  pre  post  time
# 0     1  1977  100.0  2001  74.8          24    1     2    24
# 1     1  2002   74.9  2004  70.6           2    2     2     2
# 2     1  2004   70.6  2006  70.5           2    2     2     2
# 3     1  2012   74.2  2014  74.2           2    2     2     2
# 4     1  2014   74.2  2016  73.9           2    2     2     2

# %%
import matplotlib.ticker as ticker




df = df[["pre", "post", "time"]]
# df = df[df["pre"] < 4]
# df = df[df["post"] < 5]
# df = df[df["time"]<5]
print(len(df))
r =1


fig, ax = plt.subplots()
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, pos: f"{y:,.0f}"))

ax.hist(df["time"],
        bins=50,
        color='#3A8FB7',
        edgecolor="black",
        zorder=2,
        linewidth=0.7)

ax.set_xlabel("Inspection interval [years]",fontsize=12)
ax.set_ylabel("Frequency",fontsize = 12)

# --- 背景透過設定 ---
fig.patch.set_facecolor('none')  # 図全体
ax.set_facecolor('none')         # プロット領域

# --- 保存（背景透過 + フォント埋め込みPDF） ---
fig.savefig(f"{data_name}_interval.pdf",
            format="pdf",
            transparent=True)

plt.close()
# Out:
# 9173

# %%
import seaborn as sns
counts = df.groupby(['pre', 'post']).size().unstack(fill_value=0)

# 確認
print(counts)

# 可視化（ヒートマップ）
plt.figure(figsize=(6, 4))
sns.heatmap(counts, annot=True, fmt='d', cmap='Blues')  # annot=Falseなら数字非表示
plt.xlabel('post')
plt.ylabel('pre')
plt.tight_layout()
plt.show()
# Out:
# post     1     2    3   4
# pre
# 1     2120  1315  156  30
# 2        0  4772  191  19
# 3        0     0  517  53

# %%
# likelihood process
state = np.array([df["pre"],df["post"]])
del_t = np.array(df["time"]/r)

data = np.column_stack((state.T,del_t.T))
ll = Likelihood_diagonal_exp(data)
Q = ll.optimize(np.array([-0.5,-1,-1.5]))
formater = formate_dataMatrix()
vec = formater.GetOutputVector_byDiagonal(Q)

# %%
dataset = varSets_Datasets([state],[del_t], [vec])
dataloader = DataLoader(dataset, batch_size=1,shuffle=False,collate_fn=collate_fn)
pred = []
expect = []
for a, b, c,d in dataloader:
    with torch.no_grad():
        out = model(a, b, d)
        pred = 1/out
        expect = 1/c
    print(f"output is {out}")
    print(f"target is {c}")
    print(1/out * r)
    print(1/c * r)
    out_np = out.numpy()[0]
    c_np = c.numpy()[0]
    param = np.vstack([c_np, out_np])
    a_np = a.numpy()[0].T
    b_np = b.numpy().T
    
    sample_block = np.column_stack([a_np,b_np])
    all_data = np.vstack([param, sample_block])
    df = pd.DataFrame(all_data, )
    display(df.tail(10))
    
    df = df[df[0] < 3.5]
    display(df.tail(10))
    print(df[0].unique())
    df.to_csv("BCI.csv", index=False,header=False)
# Out:
# output is tensor([[0.0759, 0.0110, 0.0158]])
# target is tensor([[0.0818, 0.0111, 0.0199]])
# tensor([[13.1725, 91.1443, 63.3419]])
# tensor([[12.2310, 90.2424, 50.2671]])
#         0    1     2
# 9165  2.0  2.0   2.0
# 9166  1.0  2.0  39.0
# 9167  2.0  2.0   2.0
# 9168  2.0  2.0   2.0
# 9169  2.0  2.0   2.0
# 9170  1.0  2.0  23.0
# 9171  2.0  2.0   2.0
# 9172  2.0  2.0   2.0
# 9173  2.0  2.0   2.0
# 9174  2.0  2.0   2.0
#         0    1     2
# 9165  2.0  2.0   2.0
# 9166  1.0  2.0  39.0
# 9167  2.0  2.0   2.0
# 9168  2.0  2.0   2.0
# 9169  2.0  2.0   2.0
# 9170  1.0  2.0  23.0
# 9171  2.0  2.0   2.0
# 9172  2.0  2.0   2.0
# 9173  2.0  2.0   2.0
# 9174  2.0  2.0   2.0
# [0.08175971 0.07591588 1.         2.         3.        ]

# %% [markdown]
# pred by 0911
# output is tensor([[0.0600, 0.0434, 0.0229]])
# target is tensor([[0.0448, 0.0530, 0.0258]])
# tensor([[16.6536, 23.0492, 43.7582]])
# tensor([[22.3031, 18.8850, 38.6929]])

# %%
colors = ['#3A8FB7', '#90B44B', '#EFBB24', '#D05A6E']
plt.rcParams["figure.figsize"] = (8, 5)

sequence = np.arange(0, 100, 0.01)

def generate_Q_from_diagonal(vec):
    Q = np.zeros((4,4))
    for i in range(len(vec)):
        Q[i,i+1]= vec[i]
        Q[i,i] = -Q[i,i+1]
    return Q

def plot_trueline(vec, ax):
    true_vecs = []
    true_Q = generate_Q_from_diagonal(vec/r)
    for t in sequence:
        P = expm(true_Q * t)
        true_vecs.append(P[0])
    true_vecs = np.array(true_vecs)

    ax.plot(sequence,true_vecs[:,0],linestyle = "--",color = "black",lw = 2, )
    ax.plot(sequence,true_vecs[:,0]+true_vecs[:,1],linestyle = "--",color = "black",lw = 2, )
    ax.plot(sequence,true_vecs[:,0]+true_vecs[:,1]+true_vecs[:,2],linestyle = "--",color = "black",lw = 2, )


def visualize(Q, title):
    fig, ax = plt.subplots()

    # プロット領域だけ白、それ以外透明
    fig.patch.set_alpha(0.0)
    ax.set_facecolor("white")
    ax.patch.set_alpha(1.0)

    vecs = []
    for t in sequence:
        P = expm(Q * t)
        vecs.append(P[0])
    vecs = np.array(vecs)

    for i, vec in enumerate(vecs):
        bottom = 0
        for j, value in enumerate(vec):
            ax.bar(sequence[i], value, bottom=bottom, color=colors[j], width=0.03,edgecolor="none",alpha=1.0,
                     
                   label=f"Condition state {j+1}" if i==0 else "")
            bottom += value

    plot_trueline(c[0], ax)

    ax.tick_params(axis='x', labelsize=12, direction='in', length=8)
    ax.tick_params(axis='y', labelsize=12, direction='in', length=8)
    ax.set_xlabel("Elapsed time [years]", fontsize=12)
    ax.set_ylabel("Proportion", fontsize=12)
    ax.set_title(title, fontsize=14)
    ax.set_ylim(0,1)
    handles, labels = ax.get_legend_handles_labels()

    fig.legend(
        handles, labels,
        loc='upper center',
        ncol=2,
        bbox_to_anchor=(0.5, 1.05),
        fontsize=12,
        frameon=False  # ← 透明化に重要
    )

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(f"{data_name}_result.pdf", transparent=True,bbox_inches='tight')
    plt.show()


# ==== 実行 ==========================================
print("代理モデルによる劣化推移予測")
visualize(generate_Q_from_diagonal(out[0]), "")
# ====================================================
# Out:
# 代理モデルによる劣化推移予測
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[68], line 74
#      72 # ==== 実行 ==========================================
#      73 print("代理モデルによる劣化推移予測")
# ---> 74 visualize(generate_Q_from_diagonal(out[0]), "")
#      75 # ====================================================
#
# Cell In[68], line 43, in visualize(Q, title)
#      41     bottom = 0
#      42     for j, value in enumerate(vec):
# ---> 43         ax.bar(sequence[i], value, bottom=bottom, color=colors[j], width=0.03,edgecolor="none",alpha=1.0,
#      44
#      45                label=f"Condition state {j+1}" if i==0 else "")
#      46         bottom += value
#      48 plot_trueline(c[0], ax)
#
# File /opt/anaconda3/envs/kisozemi/lib/python3.11/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda3/envs/kisozemi/lib/python3.11/site-packages/matplotlib/axes/_axes.py:2660, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2658     else:  # horizontal
#    2659         r.sticky_edges.x.append(l)
# -> 2660     self.add_patch(r)
#    2661     patches.append(r)
#    2663 if xerr is not None or yerr is not None:
#
# File /opt/anaconda3/envs/kisozemi/lib/python3.11/site-packages/matplotlib/axes/_base.py:2476, in _AxesBase.add_patch(self, p)
#    2474 if p.get_clip_path() is None:
#    2475     p.set_clip_path(self.patch)
# -> 2476 self._update_patch_limits(p)
#    2477 self._children.append(p)
#    2478 p._remove_method = self._children.remove
#
# File /opt/anaconda3/envs/kisozemi/lib/python3.11/site-packages/matplotlib/axes/_base.py:2502, in _AxesBase._update_patch_limits(self, patch)
#    2500     _, dzeros = curve.axis_aligned_extrema()
#    2501     # Calculate vertices of start, end and any extrema in between
# -> 2502     vertices.append(curve([0, *dzeros, 1]))
#    2504 if len(vertices):
#    2505     vertices = np.vstack(vertices)
#
# File /opt/anaconda3/envs/kisozemi/lib/python3.11/site-packages/matplotlib/bezier.py:223, in BezierSegment.__call__(self, t)
#     209 """
#     210 Evaluate the Bézier curve at point(s) *t* in [0, 1].
#     211
#    (...)
#     220     Value of the curve for each point in *t*.
#     221 """
#     222 t = np.asarray(t)
# --> 223 return (np.power.outer(1 - t, self._orders[::-1])
#     224         * np.power.outer(t, self._orders)) @ self._px
#
# KeyboardInterrupt:

# %%
import os
os.system("pdffonts shoban.pdf")
# Out:
# sh: pdffonts: command not found
# 32512

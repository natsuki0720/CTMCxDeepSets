# %%
import sys
import os
sys.path.append(os.path.abspath("../"))  # or "../../" depending on location

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from utils.likelihood import *
from utils.formate_matrix_toMLData import *
from models.model_for_lognormal import *
import matplotlib.pyplot as plt
import japanize_matplotlib
plt.rcParams["font.size"] = 22
np.set_printoptions(suppress=True)

# %%
data_dir = "../datas/test_data_0"
test_states = []
test_del_t = []
test_targets = []
dataset = []
data_formater = formate_dataMatrix()

def process_file(file_path):
    #ファイルの読み込み
    with open(file_path,encoding="utf-8-sig") as f:
        all_matrix = np.loadtxt(f, delimiter= ",")
    tm = matrix_trimer(all_matrix)
    trm = tm.trim_transitionRateMatrix()
    data = tm.trim_data()
    dataset.append(data)
    output_vec = np.array(data_formater.GetOutputVector_byDiagonal(trm))
    
    state = np.stack([data[:,0], data[:,1]], axis=0)
    test_states.append(state)
    
    test_del_t.append(data[:, 2])
    
    test_targets.append(output_vec)
    print(file_path)

data_formater.process_all_files_in_directory(data_dir,process_file)


# データセットとデータローダーの作成
test_dataset = varSets_Datasets(test_states, test_del_t, test_targets)
test_dataloader = DataLoader(test_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn)
data_iter = iter(test_dataloader)
# Out:
# ../datas/test_data_0\0_30000_4.csv
# ../datas/test_data_0\100_30000_4.csv
# ../datas/test_data_0\101_30000_4.csv
# ../datas/test_data_0\102_30000_4.csv
# ../datas/test_data_0\103_30000_4.csv
# ../datas/test_data_0\104_30000_4.csv
# ../datas/test_data_0\105_30000_4.csv
# ../datas/test_data_0\106_30000_4.csv
# ../datas/test_data_0\107_30000_4.csv
# ../datas/test_data_0\108_30000_4.csv
# ../datas/test_data_0\109_30000_4.csv
# ../datas/test_data_0\10_30000_4.csv
# ../datas/test_data_0\110_30000_4.csv
# ../datas/test_data_0\111_30000_4.csv
# ../datas/test_data_0\112_30000_4.csv
# ../datas/test_data_0\113_30000_4.csv
# ../datas/test_data_0\114_30000_4.csv
# ../datas/test_data_0\115_30000_4.csv
# ../datas/test_data_0\116_30000_4.csv
# ../datas/test_data_0\117_30000_4.csv
# ../datas/test_data_0\118_30000_4.csv
# ../datas/test_data_0\119_30000_4.csv
# ../datas/test_data_0\11_30000_4.csv
# ../datas/test_data_0\120_30000_4.csv
# ../datas/test_data_0\121_30000_4.csv
# ../datas/test_data_0\122_30000_4.csv
# ../datas/test_data_0\123_30000_4.csv
# ../datas/test_data_0\124_30000_4.csv
# ../datas/test_data_0\125_30000_4.csv
# ../datas/test_data_0\126_30000_4.csv
# ../datas/test_data_0\127_30000_4.csv
# ../datas/test_data_0\128_30000_4.csv
# ../datas/test_data_0\129_30000_4.csv
# ../datas/test_data_0\12_30000_4.csv
# ../datas/test_data_0\130_30000_4.csv
# ../datas/test_data_0\131_30000_4.csv
# ../datas/test_data_0\132_30000_4.csv
# ../datas/test_data_0\133_30000_4.csv
# ../datas/test_data_0\134_30000_4.csv
# ../datas/test_data_0\52_30000_4.csv
# ../datas/test_data_0\53_30000_4.csv
# ../datas/test_data_0\54_30000_4.csv
# ../datas/test_data_0\55_30000_4.csv
# ../datas/test_data_0\56_30000_4.csv
# ../datas/test_data_0\57_30000_4.csv
# ../datas/test_data_0\58_30000_4.csv
# ../datas/test_data_0\59_30000_4.csv
# ../datas/test_data_0\5_30000_4.csv
# ../datas/test_data_0\60_30000_4.csv
# ../datas/test_data_0\61_30000_4.csv
# ../datas/test_data_0\62_30000_4.csv
# ../datas/test_data_0\63_30000_4.csv
# ../datas/test_data_0\64_30000_4.csv
# ../datas/test_data_0\65_30000_4.csv
# ../datas/test_data_0\66_30000_4.csv
# ../datas/test_data_0\67_30000_4.csv
# ../datas/test_data_0\68_30000_4.csv
# ../datas/test_data_0\69_30000_4.csv
# ../datas/test_data_0\6_30000_4.csv
# ../datas/test_data_0\70_30000_4.csv
# ../datas/test_data_0\71_30000_4.csv
# ../datas/test_data_0\72_30000_4.csv
# ../datas/test_data_0\73_30000_4.csv
# ../datas/test_data_0\74_30000_4.csv
# ../datas/test_data_0\75_30000_4.csv
# ../datas/test_data_0\76_30000_4.csv
# ../datas/test_data_0\77_30000_4.csv
# ../datas/test_data_0\78_30000_4.csv
# ../datas/test_data_0\79_30000_4.csv
# ../datas/test_data_0\7_30000_4.csv
# ../datas/test_data_0\80_30000_4.csv
# ../datas/test_data_0\81_30000_4.csv
# ../datas/test_data_0\82_30000_4.csv
# ../datas/test_data_0\83_30000_4.csv
# ../datas/test_data_0\84_30000_4.csv
# ../datas/test_data_0\85_30000_4.csv
# ../datas/test_data_0\86_30000_4.csv
# ../datas/test_data_0\87_30000_4.csv
# ../datas/test_data_0\88_30000_4.csv
# ../datas/test_data_0\89_30000_4.csv
# ../datas/test_data_0\8_30000_4.csv
# ../datas/test_data_0\90_30000_4.csv
# ../datas/test_data_0\91_30000_4.csv
# ../datas/test_data_0\92_30000_4.csv
# ../datas/test_data_0\93_30000_4.csv
# ../datas/test_data_0\94_30000_4.csv
# ../datas/test_data_0\95_30000_4.csv
# ../datas/test_data_0\96_30000_4.csv
# ../datas/test_data_0\97_30000_4.csv
# ../datas/test_data_0\98_30000_4.csv
# ../datas/test_data_0\99_30000_4.csv
# ../datas/test_data_0\9_30000_4.csv

# %%
# load model
model = DeepSets_varSets_forDiagnel()
model.load_state_dict(torch.load("../model_weights\lognormal_distribution_delT\model_weights.pth"))
model.eval()
# Out:
# DeepSets_varSets_forDiagnel(
#   (embedding): Embedding(4, 2)
#   (fc1): Linear(in_features=5, out_features=32, bias=True)
#   (bn1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout1): Dropout(p=0.1, inplace=False)
#   (fc2): Linear(in_features=32, out_features=16, bias=True)
#   (bn2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc3): Linear(in_features=16, out_features=64, bias=True)
#   (dropout3): Dropout(p=0.3, inplace=False)
#   (fc4): Linear(in_features=64, out_features=32, bias=True)
#   (dropout4): Dropout(p=0.1, inplace=False)
#   (fc5): Linear(in_features=32, out_features=3, bias=True)
# )

# %%
loss_list = []
outs_lifespan = []
true_lifespan = []
class all_lifespan_loss(nn.Module):
    def forward(self, outputs, targets):
        epsilon = 1e-12
        y_pred_inverse = 1.0 / (outputs + epsilon)
        y_true_inverse = 1.0 / (targets + epsilon)
        
        # 逆数の差の絶対値
        loss_tensor = torch.abs(y_pred_inverse - y_true_inverse)[0]
        return loss_tensor, y_true_inverse[0], y_pred_inverse
criterion = all_lifespan_loss()

for a, b, c,d in data_iter:
    with torch.no_grad():
        out = model(a, b, d)[0]
        loss, true_expect ,pred_expect= criterion(out,c)
        
        for i in range(3):
            true_lifespan.append(true_expect[i].item())
            outs_lifespan.append(pred_expect[i].item())

df = pd.DataFrame()
df["true"] = true_lifespan
df["pred"] = outs_lifespan
df["loss"] = (df["true"] - df["pred"]).abs()

# %%
plt.figure(figsize=(6,6))
x = np.linspace(0, 100, 1000)

plt.xlim(0,100)
plt.ylim(0,100)
plt.xlabel("最尤推定による期待寿命（年）")
plt.ylabel("代理モデルの推定期待寿命（年）")
plt.plot(x,x,color="#000000", linestyle = '--',zorder= 0)
plt.scatter(df["true"],df["pred"],color = "#d69c6a",edgecolors="#d79e6b",s = 20,  zorder= 1)

# %%
# # 水道管 12.3が良さそう
r = 12.3
real_data_dir = "../real_data/suidou.csv"
df = pd.read_csv(real_data_dir,delimiter=",")
df = df[["建設時健全度（1と仮定）","調査時健全度","経過年数"]]
df.columns = ["pre", "post", "time"]
plt.hist(df["time"],bins=10)
plt.xlabel("点検間隔（年）")
plt.ylabel("頻度")
# plt.title("水道管の点検間隔の分布")
print(len(df))
# Out:
# 4343

# %%
# likelihood process
state = np.array([df["pre"],df["post"]])
del_t = np.array(df["time"]/r)

data = np.column_stack((state.T,del_t.T))
ll = Likelihood_diagonal_exp(data)
Q = ll.optimize(np.array([-0.5,-1,-1.5]))
formater = formate_dataMatrix()
vec = formater.GetOutputVector_byDiagonal(Q)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[114], line 7
#       5 data = np.column_stack((state.T,del_t.T))
#       6 ll = Likelihood_diagonal_exp(data)
# ----> 7 Q = ll.optimize(np.array([-0.5,-1,-1.5]))
#       8 formater = formate_dataMatrix()
#       9 vec = formater.GetOutputVector_byDiagonal(Q)
#
# File c:\Users\natsu\Documents\python\CTMC_MLE\utils\likelihood.py:150, in Likelihood_diagonal_exp.optimize(self, vec)
#     149 def optimize(self, vec):
# --> 150     result = minimize(self.log_likelihood, vec, method="BFGS",options={'gtol': 1e-5, 'maxiter': 1000, 'disp': False})
#     151     return self.generate_Q_from_r(result.x)
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_minimize.py:708, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     706     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     707 elif meth == 'bfgs':
# --> 708     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     709 elif meth == 'newton-cg':
#     710     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     711                              **options)
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_optimize.py:1398, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, c1, c2, hess_inv0, **unknown_options)
#    1395 pk = -np.dot(Hk, gfk)
#    1396 try:
#    1397     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1398              _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1399                                   old_fval, old_old_fval, amin=1e-100,
#    1400                                   amax=1e100, c1=c1, c2=c2)
#    1401 except _LineSearchError:
#    1402     # Line search failed to find a better solution.
#    1403     warnflag = 2
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_optimize.py:1134, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1120 """
#    1121 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#    1122 suitable step length is not found, and raise an exception if a
#    (...)
#    1129
#    1130 """
#    1132 extra_condition = kwargs.pop('extra_condition', None)
# -> 1134 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1135                          old_fval, old_old_fval,
#    1136                          **kwargs)
#    1138 if ret[0] is not None and extra_condition is not None:
#    1139     xp1 = xk + ret[0] * pk
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_linesearch.py:94, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      90     return np.dot(gval[0], pk)
#      92 derphi0 = np.dot(gfk, pk)
# ---> 94 stp, fval, old_fval = scalar_search_wolfe1(
#      95         phi, derphi, old_fval, old_old_fval, derphi0,
#      96         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      98 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_linesearch.py:171, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     168 maxiter = 100
#     170 dcsrch = DCSRCH(phi, derphi, c1, c2, xtol, amin, amax)
# --> 171 stp, phi1, phi0, task = dcsrch(
#     172     alpha1, phi0=phi0, derphi0=derphi0, maxiter=maxiter
#     173 )
#     175 return stp, phi1, phi0
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_dcsrch.py:256, in DCSRCH.__call__(self, alpha1, phi0, derphi0, maxiter)
#     254     alpha1 = stp
#     255     phi1 = self.phi(stp)
# --> 256     derphi1 = self.derphi(stp)
#     257 else:
#     258     break
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_linesearch.py:88, in line_search_wolfe1.<locals>.derphi(s)
#      87 def derphi(s):
# ---> 88     gval[0] = fprime(xk + s*pk, *args)
#      89     gc[0] += 1
#      90     return np.dot(gval[0], pk)
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_differentiable_functions.py:284, in ScalarFunction.grad(self, x)
#     282 if not np.array_equal(x, self.x):
#     283     self._update_x_impl(x)
# --> 284 self._update_grad()
#     285 return self.g
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_differentiable_functions.py:267, in ScalarFunction._update_grad(self)
#     265 def _update_grad(self):
#     266     if not self.g_updated:
# --> 267         self._update_grad_impl()
#     268         self.g_updated = True
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_differentiable_functions.py:181, in ScalarFunction.__init__.<locals>.update_grad()
#     179 self._update_fun()
#     180 self.ngev += 1
# --> 181 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     182                            **finite_diff_options)
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_numdiff.py:590, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     588     x = x0 + h_vecs[i]
#     589     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 590     df = fun(x) - f0
#     591 elif method == '3-point' and use_one_sided[i]:
#     592     x1 = x0 + h_vecs[i]
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\optimize\_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File c:\Users\natsu\Documents\python\CTMC_MLE\utils\likelihood.py:145, in Likelihood_diagonal_exp.log_likelihood(self, r_vec)
#     143 Q = self.generate_Q_from_r(r_vec)
#     144 for sample in self.data:
# --> 145     prob_m = expm(Q * sample[2])
#     146     likelihood += np.log(prob_m[int(sample[0] - 1)][int(sample[1])-1] +1e-12)
#     147 return -likelihood
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\scipy\linalg\_matfuncs.py:362, in expm(A)
#     360 # Zero out the entries from np.empty in case of triangular input
#     361 if (lu[0] == 0) or (lu[1] == 0):
# --> 362     eA[ind] = np.triu(eAw) if lu[0] == 0 else np.tril(eAw)
#     363 else:
#     364     eA[ind] = eAw
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\numpy\lib\twodim_base.py:524, in triu(m, k)
#     487 """
#     488 Upper triangle of an array.
#     489
#    (...)
#     521
#     522 """
#     523 m = asanyarray(m)
# --> 524 mask = tri(*m.shape[-2:], k=k-1, dtype=bool)
#     526 return where(mask, zeros(1, m.dtype), m)
#
# File c:\Users\natsu\anaconda3\envs\kisozemi\Lib\site-packages\numpy\lib\twodim_base.py:415, in tri(N, M, k, dtype, like)
#     411 if M is None:
#     412     M = N
#     414 m = greater_equal.outer(arange(N, dtype=_min_int(0, N)),
# --> 415                         arange(-k, M-k, dtype=_min_int(-k, M - k)))
#     417 # Avoid making a copy if the requested type is already bool
#     418 m = m.astype(dtype, copy=False)
#
# KeyboardInterrupt:

# %%
dataset = varSets_Datasets([state],[del_t], [vec])
dataloader = DataLoader(dataset, batch_size=1,shuffle=False,collate_fn=collate_fn)
pred = []
expect = []
for a, b, c,d in dataloader:
    with torch.no_grad():
        out = model(a, b, d)
        pred = 1/out
        expect = 1/c    
    print(f"output is {out}")
    print(f"target is {c}")
# Out:
# output is tensor([[0.5420, 0.6777, 0.1961]])
# target is tensor([[0.5515, 0.6513, 0.3179]])

# %%
colors= ['#6b89a9', '#8ea978', '#d69c6a', '#a55a5b'] #彩度下げ冷暖色
plt.rcParams["figure.figsize"] = (8, 5)

sequence = np.arange(0, 100, 0.01)
def visualize(Q,title):
    vecs = []
    for t in sequence:
        P = expm(Q * t)
        vecs.append(P[0])
    
    for i, vec in enumerate(vecs):
        bottom = 0
        # vec = vec[::-1]
    
        for j, value in enumerate(vec):
            plt.bar(sequence[i], value, bottom=bottom, color=colors[j],width=0.01)
            bottom += value
    for i in range(len(colors)):
        plt.scatter([],[], color = colors[i],label = f"Condition state {i+1}")
    vecs = np.array(vecs)
    
    plot_trueline(c[0])
    plt.tick_params(axis='x', labelsize=14, direction='in', length=10)
    plt.tick_params(axis='y', labelsize=14, direction='in', length=10)
    plt.xlabel("Elapsed time (year)", fontsize = 22)
    plt.ylabel("Ratio", fontsize = 22)
    # plt.title(title, fontsize = 18)
    plt.legend(loc = "lower left")
    plt.show()
    
def generate_Q_from_diagonal(vec):
        Q = np.zeros((4,4))
        for i in range(len(vec)):
            Q[i,i+1]= vec[i]
            Q[i,i] = -Q[i,i+1]
        return Q
def plot_trueline(vec):
    true_vecs = []
    true_Q = generate_Q_from_diagonal(vec/r)
    for t in sequence:
        P = expm(true_Q * t)
        true_vecs.append(P[0])
    true_vecs = np.array(true_vecs)
    
    plt.plot(sequence,true_vecs[:,0],linestyle = "--",color = "black",lw = 4)
    plt.plot(sequence,true_vecs[:,0]+true_vecs[:,1],linestyle = "-.",color = "black",lw = 4)
    plt.plot(sequence,true_vecs[:,0]+true_vecs[:,1]+true_vecs[:,2],linestyle = ":",color = "black",lw = 4)
    

print("代理モデルによる劣化推移予測")
visualize(generate_Q_from_diagonal(out[0]/r),"代理モデルによる劣化推移予測")
# Out:
# 代理モデルによる劣化推移予測
